# %% [markdown]
# Extract Data From Customers JSON File - Lesson 35
#
# 1. Query Single File
# 2. Query List of Files using wildcard Chars
# 3. Query all the files in a Folder

# %% [markdown]
# 1. Query Single JSON File

# %%
# %fs ls /Volumes/gizmobox/landing/operational_data/customers

# %%
# %sql
SELECT * FROM json.`dbfs:/Volumes/gizmobox/landing/operational_data/customers/`

# %% [markdown]
# SELECT File Metadata

# %%
# %sql
SELECT 
*
FROM json.`/Volumes/gizmobox/landing/operational_data/customers/`

# %%
# %sql
    
SELECT _metadata.file_path,
*
FROM json.`/Volumes/gizmobox/landing/operational_data/customers/`

# %% [markdown]
# 5. Register Files in Unity Catalog using views

# %%
# %sql
CREATE OR REPLACE VIEW gizmobox.bronze.v_customers AS
SELECT _metadata.file_path,
*
FROM json.`/Volumes/gizmobox/landing/operational_data/customers/`

# %%
# %sql
CREATE OR REPLACE VIEW gizmobox.bronze.v_customers AS
SELECT _metadata.file_path,
*
FROM json.`/Volumes/gizmobox/landing/operational_data/customers/`

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW v_customers AS
SELECT _metadata.file_path,
*
FROM json.`/Volumes/gizmobox/landing/operational_data/customers/`

# %%
# %sql
select * from v_customers
