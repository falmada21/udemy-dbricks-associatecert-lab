# %% [markdown]
# # Extract Data From Payments Data
#    Read in the payments data

# %%
# Extract Data From Payments Data
# Read in the payments data from external location
dbutils.fs.ls('abfss://gizmobox@optronstore.dfs.core.windows.net/landing/external_data/payments')

# %% [markdown]
# create external table

# %%
# %sql
CREATE TABLE IF NOT EXISTS gizmobox.bronze.payments
  (
    payment_id INTEGER, 
    order_id INTEGER,
    payment_timestamp TIMESTAMP, 
    payment_status INTEGER, 
    payment_method STRING)
    USING CSV
    OPTIONS (
      header = "true",
      delimeter = ","
    )
    LOCATION 'abfss://gizmobox@optronstore.dfs.core.windows.net/landing/external_data/payments'

# %%
# %sql
SELECT * FROM gizmobox.bronze.payments;

# %%
# %sql
DESCRIBE EXTENDED gizmobox.bronze.payments;

# %% [markdown]
# Add / Update / delete Files

# %% [markdown]
# Demo on droping the table

# %%
# %sql
DROP TABLE IF EXISTS gizmobox.bronze.payments;
