# %% [markdown]
# Transform Orders Data - Explode Arrays -- lesson 54
#
#
# 1. Access elements from the JSON obbject
# 2. Deduplicate Array Elements
# 3. Explode Arrays
# 4. Write the Transformed Data to Silver Schema

# %%
# %sql

SELECT 
*
FROM gizmobox.silver.orders_json;

# %% [markdown]
# Select from Orders JSON data

# %%
# %sql

SELECT json_value.order_id,
    json_value.order_date,
    json_value.order_status,
    json_value.customer_id,
    json_value.items
FROM gizmobox.silver.orders_json;

# %% [markdown]
# 2. Deduplicate Array Elements

# %%
# %sql

SELECT json_value.order_id,
    json_value.order_date,
    json_value.order_status,
    json_value.customer_id,
    array_distinct(json_value.items) AS items
FROM gizmobox.silver.orders_json;

# %%
# %sql 

--3. Explode Arrays
CREATE OR REPLACE TEMP VIEW tv_orders_exploded AS
SELECT json_value.order_id,
    json_value.order_date,
    json_value.order_status,
    json_value.customer_id,
    explode(array_distinct(json_value.items)) AS items
FROM gizmobox.silver.orders_json;

# %% [markdown]
# 4.  Write the Transformed Data to Silver Schema

# %%
# %sql

CREATE TABLE IF NOT EXISTS gizmobox.silver.orders 
AS
SELECT 
order_id,
order_date,
order_status,
customer_id,
items.item_id,
items.name,
items.price,
items.quantity,
items.category,
items.details.brand,
items.details.color
FROM tv_orders_exploded;

# %%
# %sql

SELECT * FROM gizmobox.silver.orders;
